# %%
import pandas as pd
import numpy as np

# %%
# import dataset and check missing values
df = pd.read_csv('StudentsPerformance.csv')
df = df.dropna()
df.columns = ['gender',
              'race_ethnicity',
              'parental_level_of_education',
              'lunch',
              'test_preparation_course',
              'math_score',
              'reading_score',
              'writing_score'
             ]
df
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
# describe the 3 types of score
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# visualize the outliers of score
df.boxplot()

# %%
# Remove the score outliers from df
df = df[np.abs(df['math_score']-df['math_score'].mean()) <= (3*df['math_score'].std())]
df = df[np.abs(df['reading_score']-df['reading_score'].mean()) <= (3*df['reading_score'].std())]
df_cleaned = df[np.abs(df['writing_score']-df['writing_score'].mean()) <= (3*df['writing_score'].std())]
df_cleaned
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
df.boxplot()

# %%
df_cleaned['parental_level_of_education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
df_cleaned['race_ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
# quantify parental_level_of_education
df_cleaned['parental_level_of_education'] = df_cleaned['parental_level_of_education'].map({'some high school': 0,
                                                                                          'high school': 1,
                                                                                          "associate's degree": 2,
                                                                                          'some college': 3,
                                                                                          "bachelor's degree": 4,
                                                                                          "master's degree": 5})

# %%
# quantify race_ethnicity
dummies1 = pd.get_dummies(df_cleaned.race_ethnicity)
dummies1
# Out:
#      group A  group B  group C  group D  group E
# 0          0        1        0        0        0
# 1          0        0        1        0        0
# 2          0        1        0        0        0
# 3          1        0        0        0        0
# 4          0        0        1        0        0
# 5          0        1        0        0        0
# 6          0        1        0        0        0
# 7          0        1        0        0        0
# 8          0        0        0        1        0
# 9          0        1        0        0        0
# 10         0        0        1        0        0
# 11         0        0        0        1        0
# 12         0        1        0        0        0
# 13         1        0        0        0        0
# 14         1        0        0        0        0
# 15         0        0        1        0        0
# 16         0        0        1        0        0
# 18         0        0        1        0        0
# ...

# %%
# quantify gender
dummies2 = pd.get_dummies(df_cleaned['gender'])
dummies2
# Out:
#      female  male
# 0         1     0
# 1         1     0
# 2         1     0
# 3         0     1
# 4         0     1
# 5         1     0
# 6         1     0
# 7         0     1
# 8         0     1
# 9         1     0
# 10        0     1
# 11        0     1
# 12        1     0
# 13        0     1
# 14        1     0
# 15        1     0
# 16        0     1
# 18        0     1
# 19        1     0
# 20        0     1
# 21        1     0
# 22        0     1
# 23        1     0
# 24        0     1
# 25        0     1
# 26        0     1
# 27        1     0
# 28        0     1
# 29        1     0
# 30        1     0
# ..      ...   ...
# 969       1     0
# 970       1     0
# 971       0     1
# 972       1     0
# 973       1     0
# 974       1     0
# 975       1     0
# 976       0     1
# 977       0     1
# 978       0     1
# 979       1     0
# 981       0     1
# 982       0     1
# 983       1     0
# 984       1     0
# 985       0     1
# 986       1     0
# 987       0     1
# ...

# %%
#quantify test_preparation_course
df_cleaned['test_preparation_course'] = df_cleaned['test_preparation_course'].map({'none': 0,'completed': 1})

# %%
# merge dummies into df
df_quant = pd.concat([df_cleaned,dummies1,dummies2],axis='columns')
df_quant
# Out:
#      gender race_ethnicity  parental_level_of_education         lunch  \
# 0    female        group B                            4      standard
# 1    female        group C                            3      standard
# 2    female        group B                            5      standard
# 3      male        group A                            2  free/reduced
# 4      male        group C                            3      standard
# 5    female        group B                            2      standard
# 6    female        group B                            3      standard
# 7      male        group B                            3  free/reduced
# 8      male        group D                            1  free/reduced
# 9    female        group B                            1  free/reduced
# 10     male        group C                            2      standard
# 11     male        group D                            2      standard
# ...

# %%
df_quant = df_quant.drop(['gender','race_ethnicity','group A','male'],axis='columns')

df_quant
# Out:
#      parental_level_of_education         lunch  test_preparation_course  \
# 0                              4      standard                        0
# 1                              3      standard                        1
# 2                              5      standard                        0
# 3                              2  free/reduced                        0
# 4                              3      standard                        0
# 5                              2      standard                        0
# 6                              3      standard                        1
# 7                              3  free/reduced                        0
# 8                              1  free/reduced                        1
# 9                              1  free/reduced                        0
# 10                             2      standard                        0
# 11                             2      standard                        0
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
from pymatch.Matcher import Matcher
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
# creat test and control groups
test = df_cleaned[df_quant.lunch == "free/reduced"]
control = df_cleaned[df_quant.lunch == "standard"]
test['lunch'] = 1
control['lunch'] = 0

# %%
# Matcher
m = Matcher(test, control, yvar="lunch", exclude=['math_score','reading_score','writing_score'])
# Out:
# Formula:
# lunch ~ gender+race_ethnicity+parental_level_of_education+test_preparation_course
# n majority: 643
# n minority: 350

# %%
# for reproducibility
np.random.seed(20170925)
m.fit_scores(balance=True, nmodels=300)
# Out:
# Fitting Models on Balanced Samples: 300\300
# Average Accuracy: 53.55%

# %%
# pridict scores
m.predict_scores()
m.plot_scores()

# %%
# tune threshold
m.tune_threshold(method='random')

# %%
# match data
m.match(method="min", nmatches=1, threshold=0.0004)
m.record_frequency()
# Out:
#     freq  n_records
# 0      1        367
# 1      2         17
# 2      3         21
# 3      4         12
# 4      5         15
# 5      6          4
# 6      7          5
# 7      8          3
# 8      9          1
# 9     10          1
# 10    11          1

# %%
m.assign_weight_vector()
pairs = m.matched_data.sort_values("match_id")
w_lunch =  pairs.loc[pairs['lunch'] == 1]
w_lunch['total_score'] = w_lunch['math_score'] + w_lunch['reading_score'] + w_lunch['writing_score']
without_lunch = pairs.loc[pairs['lunch'] == 0]
without_lunch['total_score'] = without_lunch['math_score'] + without_lunch['reading_score'] + without_lunch['writing_score']
w_lunch
# Out:
#      record_id  weight  gender race_ethnicity  parental_level_of_education  \
# 0            0     1.0    male        group A                            2
# 1            1     1.0    male        group B                            3
# 2            2     1.0    male        group D                            1
# 3            3     1.0  female        group B                            1
# 4            4     1.0    male        group C                            5
# 5            5     1.0  female        group C                            2
# 6            6     1.0  female        group B                            3
# 7            7     1.0    male        group D                            4
# 8            8     1.0    male        group A                            5
# 9            9     1.0  female        group E                            5
# 10          10     1.0  female        group D                            0
# ...

# %%
miu1 = np.mean(w_lunch['total_score'])
miu2 = np.mean(without_lunch['total_score'])
sigma1 = np.std(w_lunch['total_score'])
sigma2 = np.std(without_lunch['total_score'])
sigma1_2 = np.sqrt((sigma1**2)/350 + (sigma2**2)/350)
print(sigma1_2, miu1-miu2)
# Out:
# 3.0791972828491416 -20.23999999999998

# %%
# assess matches, prop_test - prop_control
# Discrete
categorical_results = m.compare_categorical(return_table=True)

# %%
categorical_results
# Out:
#               var    before     after
# 0          gender  0.564720  1.000000
# 1  race_ethnicity  0.568335  0.987254

# %%
# continuous
cc = m.compare_continuous(return_table=True)
